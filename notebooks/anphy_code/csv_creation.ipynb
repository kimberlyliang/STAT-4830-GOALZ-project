# %%
import os
import pandas as pd
import mne
import numpy as np
from config.config import DataConfig

# %%
def convert_into_csv(text_file):
    """Convert text file into CSV with sleep stage labels"""
    data = pd.read_csv(text_file, sep='\t', header=None, names=['Stage', 'Time', 'SamplingRate'])

    output_file = text_file.replace('.txt', '_labeled.csv')
    
    os.makedirs(os.path.dirname(output_file), exist_ok=True)
        
    data.to_csv(output_file, sep='\t', index=False)
    print(f"Created CSV: {output_file}")

# %%
for subject_id in DataConfig.SUBJECTS:
    paths = DataConfig.get_subject_paths(subject_id)
    print(f"\nProcessing subject: {subject_id}")
    try:
        convert_into_csv(paths['txt'])
    except Exception as e:
        print(f"Error processing {subject_id}: {str(e)}")
# Out:
# Processing subject: EPCTL01
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL01/EPCTL01_labeled.csv
#
# Processing subject: EPCTL02
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL02/EPCTL02_labeled.csv
#
# Processing subject: EPCTL03
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL03/EPCTL03_labeled.csv
#
# Processing subject: EPCTL04
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL04/EPCTL04_labeled.csv
#
# Processing subject: EPCTL05
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL05/EPCTL05_labeled.csv
#
# Processing subject: EPCTL06
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL06/EPCTL06_labeled.csv
#
# Processing subject: EPCTL07
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL07/EPCTL07_labeled.csv
#
# Processing subject: EPCTL08
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL08/EPCTL08_labeled.csv
#
# Processing subject: EPCTL09
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL09/EPCTL09_labeled.csv
#
# Processing subject: EPCTL10
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL10/EPCTL10_labeled.csv
#
# Processing subject: EPCTL11
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL11/EPCTL11_labeled.csv
#
# Processing subject: EPCTL12
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL12/EPCTL12_labeled.csv
#
# Processing subject: EPCTL13
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL13/EPCTL13_labeled.csv
#
# Processing subject: EPCTL14
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL14/EPCTL14_labeled.csv
#
# Processing subject: EPCTL15
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL15/EPCTL15_labeled.csv
#
# Processing subject: EPCTL16
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL16/EPCTL16_labeled.csv
#
# Processing subject: EPCTL17
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL17/EPCTL17_labeled.csv
#
# Processing subject: EPCTL18
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL18/EPCTL18_labeled.csv
#
# Processing subject: EPCTL19
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL19/EPCTL19_labeled.csv
#
# Processing subject: EPCTL20
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL20/EPCTL20_labeled.csv
#
# Processing subject: EPCTL21
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL21/EPCTL21_labeled.csv
#
# Processing subject: EPCTL22
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL22/EPCTL22_labeled.csv
#
# Processing subject: EPCTL23
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL23/EPCTL23_labeled.csv
#
# Processing subject: EPCTL24
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL24/EPCTL24_labeled.csv
#
# Processing subject: EPCTL25
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL25/EPCTL25_labeled.csv
#
# Processing subject: EPCTL26
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL26/EPCTL26_labeled.csv
#
# Processing subject: EPCTL27
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL27/EPCTL27_labeled.csv
#
# Processing subject: EPCTL28
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL28/EPCTL28_labeled.csv
#
# Processing subject: EPCTL29
# Created CSV: /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL29/EPCTL29_labeled.csv

# %%
def annotate_edf_with_stages(edf_file, label_csv):
    """
    Annotate EDF file with sleep stages from CSV labels
    
    Args:
        edf_file (str): Path to the EDF file
        label_csv (str): Path to the CSV file containing sleep stage labels
        
    Returns:
        mne.io.Raw: Annotated EDF data
    """
    try:
        # Read the EDF file
        raw = mne.io.read_raw_edf(edf_file, preload=True)
        # Read the labels
        labels = pd.read_csv(label_csv, sep='\t')
        
        # Create annotations
        onset = labels['Time'].values  # Time in seconds
        duration = np.repeat(30, len(labels))  # 30-second epochs
        description = labels['Stage'].values
        
        # Create MNE annotations
        annotations = mne.Annotations(onset=onset,
                                   duration=duration,
                                   description=description)
        
        # Add annotations to the raw data
        raw.set_annotations(annotations)
        
        # Save annotated EDF (optional)
        output_file = edf_file.replace('.edf', '_annotated.edf')
        raw.save(output_file, overwrite=True)
        
        print(f"Successfully annotated: {os.path.basename(edf_file)}")
        return raw
        
    except Exception as e:
        print(f"Error processing {os.path.basename(edf_file)}: {str(e)}")
        return None

def process_subject(subject_id):
    """Process a single subject using paths from config"""
    paths = DataConfig.get_subject_paths(subject_id)
    label_csv = paths['txt'].replace('.txt', '_labeled.csv')
    
    if os.path.exists(paths['edf']) and os.path.exists(label_csv):
        raw = annotate_edf_with_stages(paths['edf'], label_csv)
        return raw
    else:
        print(f"Files not found for subject {subject_id}")
        print(f"EDF exists: {os.path.exists(paths['edf'])}")
        print(f"CSV exists: {os.path.exists(label_csv)}")
        return None

# %%
# Process all subjects
for subject_id in DataConfig.SUBJECTS:
    print(f"\nProcessing subject: {subject_id}")
    raw = process_subject(subject_id)
# Out:
# Processing subject: EPCTL01
# Extracting EDF parameters from /Users/kimberly/Documents/STAT4830/STAT-4830-GOALZ-project/Anphy Dataset/EPCTL01/EPCTL01.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 28737999  =      0.000 ... 28737.999 secs...
